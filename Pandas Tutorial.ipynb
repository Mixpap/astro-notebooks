# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as axes3d
import seaborn
import pandas as pd

# %%
#stars=pd.read_table('/home/astromix/Downloads/asu.tsv',comment='#',skiprows=44)
#stars=pd.read_csv('sTaRs.tsv',sep=';')
stars=pd.read_table('stars',comment='#',delim_whitespace=True,index_col=False)

# %%
stars.size
# Out:
# 98790

# %%
stars
# Out:
#       Cl   N   ID   B-V   Vmag  LC   Teff     L          Age    Ma
# 0      1   1  454  0.45   7.32   1  3.808  3.42   24800000.0  7.67
# 1      1   1  454  0.45   7.32   1  3.808  3.42   38200000.0  6.75
# 2      1   1  454  0.45   7.32   1  3.808  3.42   45900000.0  6.47
# 3      1   2    0  0.71   7.38   1  3.767  3.39   24700000.0  7.69
# 4      1   2    0  0.71   7.38   1  3.767  3.39   37600000.0  6.77
# 5      1   2    0  0.71   7.38   1  3.767  3.39   46600000.0  6.44
# 6      1   3  521 -0.14   9.23   5  4.150  3.02   54200000.0  5.19
# 7      1   4  462 -0.15   9.64   5  4.167  2.90   46400000.0  5.14
# 8      1   4  462 -0.15   9.64   5  4.167  2.90   58900000.0  4.92
# 9      1   4  462 -0.15   9.64   5  4.167  2.90   62100000.0  4.85
# 10     1   5  610 -0.15  10.18   5  4.167  2.69   42500000.0  4.62
# 11     1   6  535 -0.16  10.21   5  4.183  2.71   33200000.0  4.76
# 12     1   7  534 -0.13  10.31   5  4.133  2.55   59600000.0  4.24
# ...

# %%
from pandas.tools.plotting import scatter_matrix

# %%
scatter_matrix(stars[['B-V','Vmag','Teff','L','Ma']],figsize=(22,22),alpha=0.2, diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa3d1d877d0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa3d36d49d0>]], dtype=object)

# %%
from sklearn.decomposition import PCA
from sklearn import cluster
from sklearn.neighbors import NearestNeighbors

# %%
X=stars[['Teff','L','Ma']].dropna()

# %%
pca = PCA(n_components=2)
X_r = pca.fit(X).transform(X)

# %%
x,y=X_r[:,0],X_r[:,1]

# %%
plt.plot(x,y,'.')

# %%
k_means = cluster.KMeans(n_clusters=3)
k_means.fit(X)
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=3, n_init=10,
#     n_jobs=1, precompute_distances='auto', random_state=None, tol=0.0001,
#     verbose=0)

# %%
X['label']=k_means.labels_

# %%
plt.scatter(-1*X['Teff'],X['L'],c=X['label'],marker='.',alpha=0.6)

# %%
nbrs = NearestNeighbors(n_neighbors=3, algorithm='ball_tree').fit(X)

# %%
nbrs.kneighbors_graph(X)
# Out:
# <9670x9670 sparse matrix of type '<type 'numpy.float64'>'
# 	with 29010 stored elements in Compressed Sparse Row format>
