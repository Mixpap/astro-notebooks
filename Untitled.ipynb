# %%
# %matplotlib notebook
import numpy as np
import numpy.random as rnd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
import sympy as sm
import sympy.physics.vector as vc
sm.init_printing()

# %%
x,u0,L,B0,t=sm.symbols('x,u0,L,B0,t',real=True)

# %%
u=sm.Matrix([[0],[u0*sm.exp(-x**2/L**2)],[0]])
Bs=sm.Matrix([[B0],[0],[0]])

# %%
B=sm.Matrix([[B0],[t*u[1].diff(x)*B0],[0]])

# %%
B

# %%
dx=0.5
dy=0.5
dz=0.5
x=np.arange(-2.5,2.5,dx)
y=np.arange(-5,5,dy)
z=np.arange(-5,5,dz)

# %%
v0=1.
L=1.
B0=1.
def V(xx):
    return np.array([[0.],[v0*np.exp(-xx**2/L**2)]])
def B(xx,t):
    Bx=B0*np.ones(np.size(xx))
    By=-2.*B0*(v0/L**2)*xx*t*np.exp(-xx**2/L**2)
    return ([[Bx],[By]])

# %%
#for t in np.linspace(0,10,10):
X,Y=np.meshgrid(x,y)
t=100
q=plt.quiver(X,Y,B(X,t)[0],B(X,t)[1],scale=1000,angles='xy')
plt.quiverkey(q,0.1,0.95,0.5*t*B0,u"$3B_0$",color='r')

# %%
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

# %%
def u(x):
    x=np.array(x)
    L=1.
    u0=1.
    return u0*np.exp(-x**2/L**2)
def BB(xx,t):
    B0=1.
    v0=1.
    L=1.
    Bx=B0*np.ones(np.shape(xx))
    By=-2.*B0*(v0/L**2)*xx*t*np.exp(-xx**2/L**2)
    Bz=np.zeros(np.shape(xx))
    return ([[Bx],[By],[Bz]])

# %%
XX,YY,ZZ=np.meshgrid(x,y,z)

# %%
np.shape(BB(x,t)[2])
# Out:
# (1, 9, 9, 3)

# %%
fig = plt.figure()
ax = Axes3D(fig)
d=0.2
a=0.4
t=1.
xx = [a,a+d,a+d,a]
yy = [0,0,0,0]
zz = [0,0,d,d]
verts = [zip(xx, yy,zz)]
verts2 = [zip(xx, yy+u(xx),zz)]
verts3 = [zip(xx, yy+u(xx)*2.,zz)]
ax.add_collection3d(Poly3DCollection(verts,alpha=0.2))
ax.add_collection3d(Poly3DCollection(verts2))
ax.add_collection3d(Poly3DCollection(verts3))
ax.quiver3D(XX,YY,ZZ,BB(XX,t)[0],BB(XX,t)[1],BB(XX,t)[2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1344852f6ea6> in <module>()
# ----> 1 fig = plt.figure()
#       2 ax = Axes3D(fig)
#       3 d=0.2
#       4 a=0.4
#       5 t=1.
#
# NameError: name 'plt' is not defined

# %%
XX.shape,BB[0].shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-2cf1f8bbbad7> in <module>()
# ----> 1 XX.shape,BB[0].shape
#
# TypeError: 'function' object has no attribute '__getitem__'

# %%
x.shape,u.shape
# Out:
# ((9, 9, 3), (9, 9, 3))

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')

x, y, z = np.meshgrid(np.arange(-0.8, 1, 0.2),
                      np.arange(-0.8, 1, 0.2),
                      np.arange(-0.8, 1, 0.8))

u = np.sin(np.pi * x) * np.cos(np.pi * y) * np.cos(np.pi * z)
v = -np.cos(np.pi * x) * np.sin(np.pi * y) * np.cos(np.pi * z)
w = (np.sqrt(2.0 / 3.0) * np.cos(np.pi * x) * np.cos(np.pi * y) *
     np.sin(np.pi * z))

ax.quiver(x, y, z, u, v, w, length=0.1)
# Out:
# <img src="data:image/png;base64,...">
